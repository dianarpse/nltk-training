# %%
from nltk import ngrams

#load sample string

sentence ='This is a sentence'

#the number of n, n =1 means unigram
n = 1
#apply the ngrams class of nltk
unigram = ngrams(sentence, n)


print('Unigrams: {}'.format(unigrams))
for gram in unigram:
  print(gram, end=' ')
# Out:
# Unigrams: <generator object ngrams at 0x7f2258f00258>
# ('T',) ('h',) ('i',) ('s',) (' ',) ('i',) ('s',) (' ',) ('a',) (' ',) ('s',) ('e',) ('n',) ('t',) ('e',) ('n',) ('c',) ('e',)

# %%
#bigrams

n = 2
bigrams = ngrams(sentence, n)
for grams in bigrams:
  print(grams, end= ' ')
# Out:
# ('T', 'h') ('h', 'i') ('i', 's') ('s', ' ') (' ', 'i') ('i', 's') ('s', ' ') (' ', 'a') ('a', ' ') (' ', 's') ('s', 'e') ('e', 'n') ('n', 't') ('t', 'e') ('e', 'n') ('n', 'c') ('c', 'e')

# %%
#trigam

n = 3
trigrams = ngrams(sentence, n)
for gram in trigrams:
  print(gram, end =' ')
# Out:
# ('T', 'h', 'i') ('h', 'i', 's') ('i', 's', ' ') ('s', ' ', 'i') (' ', 'i', 's') ('i', 's', ' ') ('s', ' ', 'a') (' ', 'a', ' ') ('a', ' ', 's') (' ', 's', 'e') ('s', 'e', 'n') ('e', 'n', 't') ('n', 't', 'e') ('t', 'e', 'n') ('e', 'n', 'c') ('n', 'c', 'e')

# %%
words = sentence.split()
print(words)
# Out:
# ['This', 'is', 'a', 'sentence']

# %%
from nltk import ngrams

#loop three iterations
for count in range(3):
  n = count + 1
  current_grams = (words,n)
  
  #save our current ngrams
  if(n==1):
    print('Unigram:')
  elif(n == 2):
    print('\nBigram: ')
  elif(n ==3):
    print('\nTrigram: ')
    #print the n-grams of current n-gram
  for gram in current_grams:
    print(gram, end= ' ')
# Out:
# Unigram:
# ['This', 'is', 'a', 'sentence'] 1
# Bigram:
# ['This', 'is', 'a', 'sentence'] 2
# Trigram:
# ['This', 'is', 'a', 'sentence'] 3

# %%
from nltk import ngrams

sentences= 'I can finish what i started even if it will takes time'

#bigram
n = 1

unigram = ngrams(sentences,n)
for gram in unigram:
  print(gram, end =' ')
# Out:
# ('I',) (' ',) ('c',) ('a',) ('n',) (' ',) ('f',) ('i',) ('n',) ('i',) ('s',) ('h',) (' ',) ('w',) ('h',) ('a',) ('t',) (' ',) ('i',) (' ',) ('s',) ('t',) ('a',) ('r',) ('t',) ('e',) ('d',) (' ',) ('e',) ('v',) ('e',) ('n',) (' ',) ('i',) ('f',) (' ',) ('i',) ('t',) (' ',) ('w',) ('i',) ('l',) ('l',) (' ',) ('t',) ('a',) ('k',) ('e',) ('s',) (' ',) ('t',) ('i',) ('m',) ('e',)

# %%
n = 2

bigram = ngrams(sentences,n)
for gram in bigram:
  print(gram, end =' ')
# Out:
# ('I', ' ') (' ', 'c') ('c', 'a') ('a', 'n') ('n', ' ') (' ', 'f') ('f', 'i') ('i', 'n') ('n', 'i') ('i', 's') ('s', 'h') ('h', ' ') (' ', 'w') ('w', 'h') ('h', 'a') ('a', 't') ('t', ' ') (' ', 'i') ('i', ' ') (' ', 's') ('s', 't') ('t', 'a') ('a', 'r') ('r', 't') ('t', 'e') ('e', 'd') ('d', ' ') (' ', 'e') ('e', 'v') ('v', 'e') ('e', 'n') ('n', ' ') (' ', 'i') ('i', 'f') ('f', ' ') (' ', 'i') ('i', 't') ('t', ' ') (' ', 'w') ('w', 'i') ('i', 'l') ('l', 'l') ('l', ' ') (' ', 't') ('t', 'a') ('a', 'k') ('k', 'e') ('e', 's') ('s', ' ') (' ', 't') ('t', 'i') ('i', 'm') ('m', 'e')

# %%
from nltk import ngrams

n = 3

trigram = ngrams(sentences,n)
for gram in trigram:
  print(gram, end =' ')

words = sentence.split()
print(words)

#loop three iterations
for count in range(3):
  n = count + 1
  current_grams = (words,n)
  
  #save our current ngrams
  if(n == 1):
    print('Unigram: ')
  elif(n == 2):
    print('Bigram: ')
  elif(n==3):
    print('Trigram: ')
  #print the n-grams of current n-gram
  for gram in current_grams:
    print(gram, end= ' ')
# Out:
# ('I', ' ', 'c') (' ', 'c', 'a') ('c', 'a', 'n') ('a', 'n', ' ') ('n', ' ', 'f') (' ', 'f', 'i') ('f', 'i', 'n') ('i', 'n', 'i') ('n', 'i', 's') ('i', 's', 'h') ('s', 'h', ' ') ('h', ' ', 'w') (' ', 'w', 'h') ('w', 'h', 'a') ('h', 'a', 't') ('a', 't', ' ') ('t', ' ', 'i') (' ', 'i', ' ') ('i', ' ', 's') (' ', 's', 't') ('s', 't', 'a') ('t', 'a', 'r') ('a', 'r', 't') ('r', 't', 'e') ('t', 'e', 'd') ('e', 'd', ' ') ('d', ' ', 'e') (' ', 'e', 'v') ('e', 'v', 'e') ('v', 'e', 'n') ('e', 'n', ' ') ('n', ' ', 'i') (' ', 'i', 'f') ('i', 'f', ' ') ('f', ' ', 'i') (' ', 'i', 't') ('i', 't', ' ') ('t', ' ', 'w') (' ', 'w', 'i') ('w', 'i', 'l') ('i', 'l', 'l') ('l', 'l', ' ') ('l', ' ', 't') (' ', 't', 'a') ('t', 'a', 'k') ('a', 'k', 'e') ('k', 'e', 's') ('e', 's', ' ') ('s', ' ', 't') (' ', 't', 'i') ('t', 'i', 'm') ('i', 'm', 'e') ['I', 'can', 'finish', 'what', 'i', 'started', 'even', 'if', 'it', 'will', 'takes', 'time']
# Unigram:
# ['I', 'can', 'finish', 'what', 'i', 'started', 'even', 'if', 'it', 'will', 'takes', 'time'] 1 Bigram:
# ['I', 'can', 'finish', 'what', 'i', 'started', 'even', 'if', 'it', 'will', 'takes', 'time'] 2 Trigram:
# ['I', 'can', 'finish', 'what', 'i', 'started', 'even', 'if', 'it', 'will', 'takes', 'time'] 3

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-61c5cf08-9cd6-42b0-8277-8897368deb60" name="files[]" multiple disabled />
#      <output id="result-61c5cf08-9cd6-42b0-8277-8897368deb60">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving reviews.txt to reviews.txt

# %%
with open('reviews.txt', 'r') as file:
  corpus = file.read().split()

# %%
corpus
# Out:
# ['bromwell',
#  'high',
#  'is',
#  'a',
#  'cartoon',
#  'comedy',
#  '.',
#  'it',
#  'ran',
#  'at',
#  'the',
#  'same',
#  'time',
#  'as',
#  'some',
#  'other',
#  'programs',
#  'about',
#  'school',
#  'life',
#  'such',
#  'as',
#  'teachers',
#  '.',
#  'my',
#  'years',
#  'in',
#  'the',
#  'teaching',
#  'profession',
#  'lead',
#  'me',
#  'to',
#  'believe',
#  'that',
#  'bromwell',
#  'high',
#  's',
#  'satire',
#  'is',
#  'much',
#  'closer',
#  'to',
#  'reality',
#  'than',
#  'is',
#  'teachers',
#  '.',
#  'the',
#  'scramble',
#  'to',
#  'survive',
#  'financially',
#  'the',
#  'insightful',
#  'students',
#  'who',
#  'can',
#  'see',
#  'right',
#  'through',
#  'their',
#  'pathetic',
#  'teachers',
#  'pomp',
#  'the',
#  'pettiness',
#  'of',
#  'the',
#  'whole',
#  'situation',
#  'all',
#  'remind',
#  'me',
#  'of',
#  'the',
#  'schools',
#  'i',
#  'knew',
#  'and',
#  'their',
#  'students',
#  '.',
#  'when',
#  'i',
#  'saw',
#  'the',
#  'episode',
#  'in',
#  'which',
#  'a',
#  'student',
#  'repeatedly',
#  'tried',
#  'to',
#  'burn',
#  'down',
#  'the',
#  'school',
#  'i',
#  'immediately',
#  'recalled',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'at',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'high',
#  '.',
#  'a',
#  'classic',
#  'line',
#  'inspector',
#  'i',
#  'm',
#  'here',
#  'to',
#  'sack',
#  'one',
#  'of',
#  'your',
#  'teachers',
#  '.',
#  'student',
#  'welcome',
#  'to',
#  'bromwell',
#  'high',
#  '.',
#  'i',
#  'expect',
#  'that',
#  'many',
#  'adults',
#  'of',
#  'my',
#  'age',
#  'think',
#  'that',
#  'bromwell',
#  'high',
#  'is',
#  'far',
#  'fetched',
#  '.',
#  'what',
#  'a',
#  'pity',
#  'that',
#  'it',
#  'isn',
#  't',
#  'story',
#  'of',
#  'a',
#  'man',
#  'who',
#  'has',
#  'unnatural',
#  'feelings',
#  'for',
#  'a',
#  'pig',
#  '.',
#  'starts',
#  'out',
#  'with',
#  'a',
#  'opening',
#  'scene',
#  'that',
#  'is',
#  'a',
#  'terrific',
#  'example',
#  'of',
#  'absurd',
#  'comedy',
#  '.',
#  'a',
#  'formal',
#  'orchestra',
#  'audience',
#  'is',
#  'turned',
#  'into',
#  'an',
#  'insane',
#  'violent',
#  'mob',
#  'by',
#  'the',
#  'crazy',
#  'chantings',
#  'of',
#  'it',
#  's',
#  'singers',
#  '.',
#  'unfortunately',
#  'it',
#  'stays',
#  'absurd',
#  'the',
#  'whole',
#  'time',
#  'with',
#  'no',
#  'general',
#  'narrative',
#  'eventually',
#  'making',
#  'it',
#  'just',
#  'too',
#  'off',
#  'putting',
#  '.',
#  'even',
#  'those',
#  'from',
#  'the',
#  'era',
#  'should',
#  'be',
#  'turned',
#  'off',
#  '.',
#  'the',
#  'cryptic',
#  'dialogue',
#  'would',
#  'make',
#  'shakespeare',
#  'seem',
#  'easy',
#  'to',
#  'a',
#  'third',
#  'grader',
#  '.',
#  'on',
#  'a',
#  'technical',
#  'level',
#  'it',
#  's',
#  'better',
#  'than',
#  'you',
#  'might',
#  'think',
#  'with',
#  'some',
#  'good',
#  'cinematography',
#  'by',
#  'future',
#  'great',
#  'vilmos',
#  'zsigmond',
#  '.',
#  'future',
#  'stars',
#  'sally',
#  'kirkland',
#  'and',
#  'frederic',
#  'forrest',
#  'can',
#  'be',
#  'seen',
#  'briefly',
#  '.',
#  'homelessness',
#  'or',
#  'houselessness',
#  'as',
#  'george',
#  'carlin',
#  'stated',
#  'has',
#  'been',
#  'an',
#  'issue',
#  'for',
#  'years',
#  'but',
#  'never',
#  'a',
#  'plan',
#  'to',
#  'help',
#  'those',
#  'on',
#  'the',
#  'street',
#  'that',
#  'were',
#  'once',
#  'considered',
#  'human',
#  'who',
#  'did',
#  'everything',
#  'from',
#  'going',
#  'to',
#  'school',
#  'work',
#  'or',
#  'vote',
#  'for',
#  'the',
#  'matter',
#  '.',
#  'most',
#  'people',
#  'think',
#  'of',
#  'the',
#  'homeless',
#  'as',
#  'just',
#  'a',
#  'lost',
#  'cause',
#  'while',
#  'worrying',
#  'about',
#  'things',
#  'such',
#  'as',
#  'racism',
#  'the',
#  'war',
#  'on',
#  'iraq',
#  'pressuring',
#  'kids',
#  'to',
#  'succeed',
#  'technology',
#  'the',
#  'elections',
#  'inflation',
#  'or',
#  'worrying',
#  'if',
#  'they',
#  'll',
#  'be',
#  'next',
#  'to',
#  'end',
#  'up',
#  'on',
#  'the',
#  'streets',
#  '.',
#  'br',
#  'br',
#  'but',
#  'what',
#  'if',
#  'you',
#  'were',
#  'given',
#  'a',
#  'bet',
#  'to',
#  'live',
#  'on',
#  'the',
#  'streets',
#  'for',
#  'a',
#  'month',
#  'without',
#  'the',
#  'luxuries',
#  'you',
#  'once',
#  'had',
#  'from',
#  'a',
#  'home',
#  'the',
#  'entertainment',
#  'sets',
#  'a',
#  'bathroom',
#  'pictures',
#  'on',
#  'the',
#  'wall',
#  'a',
#  'computer',
#  'and',
#  'everything',
#  'you',
#  'once',
#  'treasure',
#  'to',
#  'see',
#  'what',
#  'it',
#  's',
#  'like',
#  'to',
#  'be',
#  'homeless',
#  'that',
#  'is',
#  'goddard',
#  'bolt',
#  's',
#  'lesson',
#  '.',
#  'br',
#  'br',
#  'mel',
#  'brooks',
#  'who',
#  'directs',
#  'who',
#  'stars',
#  'as',
#  'bolt',
#  'plays',
#  'a',
#  'rich',
#  'man',
#  'who',
#  'has',
#  'everything',
#  'in',
#  'the',
#  'world',
#  'until',
#  'deciding',
#  'to',
#  'make',
#  'a',
#  'bet',
#  'with',
#  'a',
#  'sissy',
#  'rival',
#  'jeffery',
#  'tambor',
#  'to',
#  'see',
#  'if',
#  'he',
#  'can',
#  'live',
#  'in',
#  'the',
#  'streets',
#  'for',
#  'thirty',
#  'days',
#  'without',
#  'the',
#  'luxuries',
#  'if',
#  'bolt',
#  'succeeds',
#  'he',
#  'can',
#  'do',
#  'what',
#  'he',
#  'wants',
#  'with',
#  'a',
#  'future',
#  'project',
#  'of',
#  'making',
#  'more',
#  'buildings',
#  '.',
#  'the',
#  'bet',
#  's',
#  'on',
#  'where',
#  'bolt',
#  'is',
#  'thrown',
#  'on',
#  'the',
#  'street',
#  'with',
#  'a',
#  'bracelet',
#  'on',
#  'his',
#  'leg',
#  'to',
#  'monitor',
#  'his',
#  'every',
#  'move',
#  'where',
#  'he',
#  'can',
#  't',
#  'step',
#  'off',
#  'the',
#  'sidewalk',
#  '.',
#  'he',
#  's',
#  'given',
#  'the',
#  'nickname',
#  'pepto',
#  'by',
#  'a',
#  'vagrant',
#  'after',
#  'it',
#  's',
#  'written',
#  'on',
#  'his',
#  'forehead',
#  'where',
#  'bolt',
#  'meets',
#  'other',
#  'characters',
#  'including',
#  'a',
#  'woman',
#  'by',
#  'the',
#  'name',
#  'of',
#  'molly',
#  'lesley',
#  'ann',
#  'warren',
#  'an',
#  'ex',
#  'dancer',
#  'who',
#  'got',
#  'divorce',
#  'before',
#  'losing',
#  'her',
#  'home',
#  'and',
#  'her',
#  'pals',
#  'sailor',
#  'howard',
#  'morris',
#  'and',
#  'fumes',
#  'teddy',
#  'wilson',
#  'who',
#  'are',
#  'already',
#  'used',
#  'to',
#  'the',
#  'streets',
#  '.',
#  'they',
#  're',
#  'survivors',
#  '.',
#  'bolt',
#  'isn',
#  't',
#  '.',
#  'he',
#  's',
#  'not',
#  'used',
#  'to',
#  'reaching',
#  'mutual',
#  'agreements',
#  'like',
#  'he',
#  'once',
#  'did',
#  'when',
#  'being',
#  'rich',
#  'where',
#  'it',
#  's',
#  'fight',
#  'or',
#  'flight',
#  'kill',
#  'or',
#  'be',
#  'killed',
#  '.',
#  'br',
#  'br',
#  'while',
#  'the',
#  'love',
#  'connection',
#  'between',
#  'molly',
#  'and',
#  'bolt',
#  'wasn',
#  't',
#  'necessary',
#  'to',
#  'plot',
#  'i',
#  'found',
#  'life',
#  'stinks',
#  'to',
#  'be',
#  'one',
#  'of',
#  'mel',
#  'brooks',
#  'observant',
#  'films',
#  'where',
#  'prior',
#  'to',
#  'being',
#  'a',
#  'comedy',
#  'it',
#  'shows',
#  'a',
#  'tender',
#  'side',
#  'compared',
#  'to',
#  'his',
#  'slapstick',
#  'work',
#  'such',
#  'as',
#  'blazing',
#  'saddles',
#  'young',
#  'frankenstein',
#  'or',
#  'spaceballs',
#  'for',
#  'the',
#  'matter',
#  'to',
#  'show',
#  'what',
#  'it',
#  's',
#  'like',
#  'having',
#  'something',
#  'valuable',
#  'before',
#  'losing',
#  'it',
#  'the',
#  'next',
#  'day',
#  'or',
#  'on',
#  'the',
#  'other',
#  'hand',
#  'making',
#  'a',
#  'stupid',
#  'bet',
#  'like',
#  'all',
#  'rich',
#  'people',
#  'do',
#  'when',
#  'they',
#  'don',
#  't',
#  'know',
#  'what',
#  'to',
#  'do',
#  'with',
#  'their',
#  'money',
#  '.',
#  'maybe',
#  'they',
#  'should',
#  'give',
#  'it',
#  'to',
#  'the',
#  'homeless',
#  'instead',
#  'of',
#  'using',
#  'it',
#  'like',
#  'monopoly',
#  'money',
#  '.',
#  'br',
#  'br',
#  'or',
#  'maybe',
#  'this',
#  'film',
#  'will',
#  'inspire',
#  'you',
#  'to',
#  'help',
#  'others',
#  '.',
#  'airport',
#  'starts',
#  'as',
#  'a',
#  'brand',
#  'new',
#  'luxury',
#  'plane',
#  'is',
#  'loaded',
#  'up',
#  'with',
#  'valuable',
#  'paintings',
#  'such',
#  'belonging',
#  'to',
#  'rich',
#  'businessman',
#  'philip',
#  'stevens',
#  'james',
#  'stewart',
#  'who',
#  'is',
#  'flying',
#  'them',
#  'a',
#  'bunch',
#  'of',
#  'vip',
#  's',
#  'to',
#  'his',
#  'estate',
#  'in',
#  'preparation',
#  'of',
#  'it',
#  'being',
#  'opened',
#  'to',
#  'the',
#  'public',
#  'as',
#  'a',
#  'museum',
#  'also',
#  'on',
#  'board',
#  'is',
#  'stevens',
#  'daughter',
#  'julie',
#  'kathleen',
#  'quinlan',
#  'her',
#  'son',
#  '.',
#  'the',
#  'luxury',
#  'jetliner',
#  'takes',
#  'off',
#  'as',
#  'planned',
#  'but',
#  'mid',
#  'air',
#  'the',
#  'plane',
#  'is',
#  'hi',
#  'jacked',
#  'by',
#  'the',
#  'co',
#  'pilot',
#  'chambers',
#  'robert',
#  'foxworth',
#  'his',
#  'two',
#  'accomplice',
#  's',
#  'banker',
#  'monte',
#  'markham',
#  'wilson',
#  'michael',
#  'pataki',
#  'who',
#  'knock',
#  'the',
#  'passengers',
#  'crew',
#  'out',
#  'with',
#  'sleeping',
#  'gas',
#  'they',
#  'plan',
#  'to',
#  'steal',
#  'the',
#  'valuable',
#  'cargo',
#  'land',
#  'on',
#  'a',
#  'disused',
#  'plane',
#  'strip',
#  'on',
#  'an',
#  'isolated',
#  'island',
#  'but',
#  'while',
#  'making',
#  'his',
#  'descent',
#  'chambers',
#  'almost',
#  'hits',
#  'an',
#  'oil',
#  'rig',
#  'in',
#  'the',
#  'ocean',
#  'loses',
#  'control',
#  'of',
#  'the',
#  'plane',
#  'sending',
#  'it',
#  'crashing',
#  'into',
#  'the',
#  'sea',
#  'where',
#  'it',
#  'sinks',
#  'to',
#  'the',
#  'bottom',
#  'right',
#  'bang',
#  'in',
#  'the',
#  'middle',
#  'of',
#  'the',
#  'bermuda',
#  'triangle',
#  '.',
#  'with',
#  'air',
#  'in',
#  'short',
#  'supply',
#  'water',
#  'leaking',
#  'in',
#  'having',
#  'flown',
#  'over',
#  'miles',
#  'off',
#  'course',
#  'the',
#  'problems',
#  'mount',
#  'for',
#  'the',
#  'survivor',
#  's',
#  'as',
#  'they',
#  'await',
#  'help',
#  'with',
#  'time',
#  'fast',
#  'running',
#  'out',
#  '.',
#  '.',
#  '.',
#  'br',
#  'br',
#  'also',
#  'known',
#  'under',
#  'the',
#  'slightly',
#  'different',
#  'tile',
#  'airport',
#  'this',
#  'second',
#  'sequel',
#  'to',
#  'the',
#  'smash',
#  'hit',
#  'disaster',
#  'thriller',
#  'airport',
#  'was',
#  'directed',
#  'by',
#  'jerry',
#  'jameson',
#  'while',
#  'once',
#  'again',
#  'like',
#  'it',
#  's',
#  'predecessors',
#  'i',
#  'can',
#  't',
#  'say',
#  'airport',
#  'is',
#  'any',
#  'sort',
#  'of',
#  'forgotten',
#  'classic',
#  'it',
#  'is',
#  'entertaining',
#  'although',
#  'not',
#  'necessarily',
#  'for',
#  'the',
#  'right',
#  'reasons',
#  '.',
#  'out',
#  'of',
#  'the',
#  'three',
#  'airport',
#  'films',
#  'i',
#  ...]

# %%
#save unigrams here
from nltk import ngrams
unigram_list =[]

#unigrams

n = 1

unigrams = ngrams(corpus,n)

for gram in unigrams:
  unigram_list.append(gram)

# %%
print(unigram_list[:20])
# Out:
# [('bromwell',), ('high',), ('is',), ('a',), ('cartoon',), ('comedy',), ('.',), ('it',), ('ran',), ('at',), ('the',), ('same',), ('time',), ('as',), ('some',), ('other',), ('programs',), ('about',), ('school',), ('life',)]

# %%
from collections import defaultdict

#create a default dictionary

dictionary = defaultdict(list)


#make a temporary value for the previous word

previous_word=''

#loop for appending values to the dictionary
for current_word in unigram_list:
  if previous_word != '':
    dictionary[previous_word].append(current_word[0])
  previous_word = current_word[0]

# %%
dictionary
# Out:
# defaultdict(list,
#             {'bromwell': ['high', 'high', 'high', 'high'],
#              'high': ['is',
#               's',
#               '.',
#               '.',
#               'is',
#               'school',
#               'form',
#               'but',
#               'atop',
#               'standard',
#               'rating',
#               'time',
#               'expectations',
#               'school',
#               'school',
#               'standards',
#               'tone',
#               'even',
#               'fashion',
#               'fashion',
#               'chance',
#               'standards',
#               'fashion',
#               'a'],
#              'is': ['a',
#               'much',
#               'teachers',
#               'far',
#               'a',
#               'turned',
#               'goddard',
#               'thrown',
#               'loaded',
#               'flying',
#               'stevens',
#               'hi',
#               'any',
#               'entertaining',
#               'where',
#               'a',
#               'back',
#               'slow',
#               'generated',
#               'a',
#               'given',
#               'the',
#               'a',
#               'also',
#               'fantastic',
#               'more',
#               'quite',
#               'easily',
#               'very',
#               'truly',
#               'that',
#               'supposed',
#               'too',
#               'two',
#               'well',
#               'not',
#               'such',
#               'worth',
#               'one',
#               'by',
#               'drenched',
#               'no',
#               'painfully',
#               'lost',
#               'nothing',
#               'it',
#               'a',
#               'more',
#               'this',
#               'very',
#               'good',
#               'good',
#               'chock',
#               'exactly',
#               'exemplary',
#               'correct',
#               'that',
#               'it',
#               'the',
#               'it',
#               'naturally',
#               'dying',
#               'suddenly',
#               'planted',
#               'in',
#               'mediocre',
#               'as',
#               'the',
#               'charlie',
#               'constantly',
#               'now',
#               'among',
#               'a',
#               'based',
#               'at',
#               'like',
#               'a',
#               'bad',
#               'no',
#               'weak',
#               'or',
#               'painful',
#               'ever',
#               'in',
#               'one',
#               'utterly',
#               'about',
#               'woody',
#               'that',
#               'still',
#               'monotonous',
#               'not',
#               'so',
#               'incapable',
#               'german',
#               'bad',
#               'not',
#               'funny',
#               'several',
#               'basically',
#               'completely',
#               'the',
#               'losing',
#               'no',
#               'here',
#               'captivated',
#               'pure',
#               'not',
#               'slow',
#               'watchable',
#               'great',
#               'very',
#               'nine',
#               'a',
#               'to',
#               'not',
#               'a',
#               'about',
#               'painfully',
#               '.',
#               'because',
#               'probably',
#               'definitely',
#               'no',
#               'it',
#               'a',
#               'no',
#               'not',
#               'of',
#               'shut',
#               'definitely',
#               'very',
#               'inspired',
#               'predictable',
#               'an',
#               'a',
#               'not',
#               'that',
#               'one',
#               'that',
#               'intriguing',
#               'a',
#               'something',
#               'not',
#               'probably',
#               'certain',
#               'mostly',
#               'a',
#               'better',
#               'the',
#               'deliberate',
#               'kept',
#               'supposed',
#               'the',
#               'surely',
#               'awful',
#               'done',
#               'gay',
#               'highly',
#               'a',
#               'if',
#               'as',
#               'some',
#               'sizzling',
#               'akshay',
#               'annoying',
#               'sidey',
#               'the',
#               'difficult',
#               'now',
#               'the',
#               'unwatchable',
#               '.',
#               'chosen',
#               'the',
#               'pretty',
#               'annoying',
#               'marvelous',
#               'okay',
#               'practically',
#               'a',
#               'that',
#               'the',
#               'a',
#               'as',
#               'king',
#               'produced',
#               'bland',
#               'a',
#               'great',
#               'a',
#               'actually',
#               'similar',
#               'definitely',
#               'no',
#               'an',
#               'an',
#               'that',
#               'a',
#               'a',
#               'here',
#               'all',
#               'quite',
#               'directed',
#               'attributed',
#               'probably',
#               'quite',
#               'his',
#               'damn',
#               'memorable',
#               'why',
#               'really',
#               'absolutely',
#               'not',
#               'like',
#               'that',
#               'based',
#               'that',
#               'more',
#               'not',
#               'not',
#               'awful',
#               'there',
#               'the',
#               'the',
#               'english',
#               'the',
#               'in',
#               'outstanding',
#               'a',
#               'a',
#               'a',
#               'still',
#               'an',
#               'simply',
#               'its',
#               'somehow',
#               'too',
#               'out',
#               'miss',
#               'in',
#               'the',
#               'compared',
#               'very',
#               'the',
#               'the',
#               'worth',
#               'of',
#               'a',
#               'just',
#               'this',
#               'not',
#               'not',
#               'anthony',
#               'suprised',
#               'very',
#               'one',
#               'filmmakers',
#               'hilarious',
#               'so',
#               'the',
#               'no',
#               'the',
#               'the',
#               'superb',
#               'a',
#               'the',
#               'invited',
#               'also',
#               'a',
#               'directed',
#               'produced',
#               'good',
#               'extremely',
#               'not',
#               'mainly',
#               'my',
#               'the',
#               'always',
#               'nothing',
#               'that',
#               'truly',
#               'about',
#               'the',
#               'and',
#               'killing',
#               'crores',
#               'the',
#               'absolutely',
#               'a',
#               'the',
#               'a',
#               'not',
#               'a',
#               'better',
#               'crud',
#               'not',
#               'that',
#               'a',
#               'a',
#               'a',
#               'the',
#               'the',
#               'a',
#               'nice',
#               'entitled',
#               'a',
#               'a',
#               'the',
#               'trying',
#               'certainly',
#               'height',
#               'not',
#               'really',
#               'done',
#               'too',
#               'much',
#               'a',
#               '.',
#               'high',
#               'the',
#               'so',
#               'shown',
#               'so',
#               'simple',
#               'brilliant',
#               'their',
#               'overlong',
#               'over',
#               'overrated',
#               'perfectly',
#               'lovely',
#               'very',
#               'hot',
#               'very',
#               'a',
#               'extremely',
#               'one',
#               'the',
#               'boring',
#               'so',
#               'doing',
#               'what',
#               'he',
#               'alright',
#               'another',
#               'another',
#               'ordinary',
#               'irritating',
#               'equally',
#               'my',
#               'all',
#               'an',
#               'bad',
#               'awesome',
#               'simple',
#               'so',
#               'actually',
#               'bad',
#               'not',
#               'shoddy',
#               'abysmal',
#               'a',
#               'sure',
#               'a',
#               'doing',
#               'such',
#               'not',
#               'the',
#               'movie',
#               'long',
#               'not',
#               'good',
#               'also',
#               'filled',
#               'wait',
#               'too',
#               'very',
#               'a',
#               'going',
#               'so',
#               'a',
#               'a',
#               'poorly',
#               'extremely',
#               'that',
#               'the',
#               'shown',
#               'already',
#               'a',
#               'a',
#               'a',
#               'a',
#               'horrible',
#               'a',
#               'great',
#               'not',
#               'letting',
#               'having',
#               'enjoyable',
#               'quite',
#               'but',
#               'great',
#               'well',
#               'actually',
#               'based',
#               'european',
#               'totally',
#               'a',
#               'clear',
#               'so',
#               'exceptionally',
#               'legend',
#               'wonderful',
#               'more',
#               'quickly',
#               'rose',
#               'entirely',
#               'composer',
#               'and',
#               '.',
#               'the',
#               'memorable',
#               'at',
#               'where',
#               'the',
#               'a',
#               'the',
#               'putting',
#               'forbidden',
#               'rose',
#               'a',
#               'something',
#               'about',
#               'not',
#               'what',
#               'held',
#               'quite',
#               'nobody',
#               'like',
#               'salvaged',
#               'a',
#               'essentially',
#               'terrific',
#               'absolutely',
#               'an',
#               'the',
#               'a',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'loaded',
#               'a',
#               'overwhelming',
#               'hunting',
#               'the',
#               'the',
#               'falling',
#               'easily',
#               'an',
#               'hard',
#               'only',
#               'perfect',
#               'way',
#               'it',
#               'a',
#               'the',
#               'enough',
#               'not',
#               'injurious',
#               'in',
#               'like',
#               'supposed',
#               'simple',
#               'an',
#               'wonderful',
#               'flown',
#               'being',
#               'developed',
#               'in',
#               'accurate',
#               'very',
#               'accurate',
#               'on',
#               'hardly',
#               'recreated',
#               'a',
#               'posed',
#               'very',
#               'used',
#               'like',
#               'for',
#               'the',
#               'his',
#               'all',
#               'also',
#               'overrated',
#               'so',
#               'the',
#               'being',
#               'the',
#               'not',
#               'not',
#               'vijay',
#               'an',
#               'not',
#               'saif',
#               'not',
#               'truly',
#               'not',
#               'the',
#               'short',
#               'arrested',
#               'supposed',
#               'unclear',
#               'never',
#               'the',
#               'the',
#               'that',
#               'the',
#               'among',
#               'completely',
#               'your',
#               'never',
#               'very',
#               'huddling',
#               'perfect',
#               'so',
#               'one',
#               'beyond',
#               'one',
#               'being',
#               'brought',
#               'in',
#               'rubbish',
#               'badly',
#               'stabbed',
#               'stabbed',
#               'alright',
#               'easily',
#               'a',
#               'great',
#               'capable',
#               'not',
#               'great',
#               'primarily',
#               'done',
#               'really',
#               'human',
#               'between',
#               'a',
#               'puzzled',
#               'that',
#               'easy',
#               'not',
#               'one',
#               'that',
#               'rarely',
#               'what',
#               'about',
#               'what',
#               'about',
#               'the',
#               'one',
#               'one',
#               'surrounded',
#               'particularly',
#               'full',
#               'strong',
#               'shot',
#               'expecting',
#               'found',
#               'discovered',
#               'longer',
#               'assumed',
#               'indeed',
#               'a',
#               'completely',
#               'emma',
#               'the',
#               'worth',
#               'a',
#               'a',
#               'your',
#               'a',
#               'still',
#               'one',
#               'required',
#               'no',
#               'handled',
#               'too',
#               'more',
#               'based',
#               'interesting',
#               'energetic',
#               'there',
#               'effective',
#               'perhaps',
#               'not',
#               'very',
#               'a',
#               'a',
#               'one',
#               'superman',
#               'slightly',
#               'the',
#               'in',
#               'just',
#               'a',
#               'only',
#               'pretty',
#               'supposedly',
#               'because',
#               'an',
#               're',
#               'thrown',
#               'there',
#               'in',
#               'neat',
#               'filled',
#               'only',
#               'indicative',
#               'inescapable',
#               'we',
#               'essentially',
#               'a',
#               'gritty',
#               'so',
#               'finished',
#               'struggling',
#               'trying',
#               'the',
#               'flawless',
#               'inspired',
#               'a',
#               'edison',
#               'usually',
#               'more',
#               'something',
#               'way',
#               'an',
#               'known',
#               'a',
#               'worried',
#               'about',
#               'in',
#               'just',
#               'an',
#               'phenomenal',
#               'flawless',
#               'about',
#               'an',
#               'disturbing',
#               'a',
#               'gone',
#               'a',
#               'basically',
#               'rubbish',
#               'secure',
#               'nearly',
#               'the',
#               'sublime',
#               'actually',
#               'god',
#               'in',
#               'pleasant',
#               'keenly',
#               'probably',
#               'great',
#               'solid',
#               'with',
#               'pointless',
#               'not',
#               'just',
#               'a',
#               'childless',
#               'encouraged',
#               'lost',
#               'absorbing',
#               'serene',
#               'an',
#               'not',
#               'you',
#               'a',
#               'almost',
#               'set',
#               'no',
#               'contrasted',
#               'about',
#               'a',
#               'passed',
#               'marginally',
#               'extra',
#               'still',
#               'mediocre',
#               'a',
#               'growing',
#               'a',
#               'the',
#               'that',
#               'known',
#               'a',
#               'famous',
#               'definitely',
#               'shorter',
#               'japanese',
#               'all',
#               'great',
#               'how',
#               'a',
#               'their',
#               'very',
#               'different',
#               'the',
#               'forced',
#               'going',
#               'kind',
#               'like',
#               'just',
#               'steeped',
#               'excellent',
#               'wrongly',
#               'fun',
#               'good',
#               'not',
#               'that',
#               'worth',
#               'an',
#               'an',
#               'a',
#               'ridiculous',
#               'a',
#               'plot',
#               'the',
#               'present',
#               'the',
#               'his',
#               'because',
#               'so',
#               'with',
#               'this',
#               'so',
#               'so',
#               'usher',
#               'that',
#               'a',
#               'mr',
#               'a',
#               'charming',
#               'nothing',
#               'done',
#               'a',
#               'instantly',
#               'not',
#               'a',
#               'the',
#               'that',
#               'especially',
#               'based',
#               'an',
#               'based',
#               'not',
#               'the',
#               'we',
#               'nothing',
#               'the',
#               'the',
#               'they',
#               'sold',
#               'well',
#               'found',
#               'not',
#               'forced',
#               'always',
#               'a',
#               'for',
#               'clumsy',
#               'not',
#               'a',
#               'no',
#               'so',
#               'another',
#               'one',
#               'a',
#               'only',
#               'a',
#               'the',
#               'so',
#               'easy',
#               'ultimately',
#               'a',
#               'how',
#               'the',
#               'established',
#               'a',
#               'not',
#               'her',
#               'not',
#               'bad',
#               'probably',
#               'perfection',
#               'totally',
#               'sandy',
#               'love',
#               'or',
#               'like',
#               'just',
#               'kind',
#               'beautiful',
#               'remote',
#               'the',
#               'still',
#               'a',
#               'simple',
#               'a',
#               'obscenely',
#               'uncomfortably',
#               'an',
#               'gold',
#               'no',
#               'beautiful',
#               'feasible',
#               'a',
#               'unfair',
#               'an',
#               'gone',
#               'set',
#               'great',
#               'hugely',
#               'awful',
#               'good',
#               'simply',
#               'a',
#               'a',
#               'an',
#               'the',
#               'now',
#               '.',
#               'a',
#               'fun',
#               'rich',
#               'strong',
#               'also',
#               'nothing',
#               'so',
#               'truly',
#               'universal',
#               'that',
#               'wrong',
#               'is',
#               'that',
#               'closer',
#               'left',
#               'about',
#               'not',
#               'kind',
#               'a',
#               'how',
#               'the',
#               'staggeringly',
#               'one',
#               'absolutely',
#               'common',
#               'not',
#               'usually',
#               'possible',
#               'hunky',
#               'that',
#               'really',
#               'visually',
#               'that',
#               'so',
#               'a',
#               'nothing',
#               'a',
#               'not',
#               'now',
#               'a',
#               'probably',
#               'always',
#               'around',
#               'a',
#               'an',
#               'not',
#               'truly',
#               'as',
#               'subterranean',
#               'an',
#               'played',
#               'also',
#               'the',
#               'only',
#               'especially',
#               'where',
#               '.',
#               'it',
#               'still',
#               'a',
#               'nowhere',
#               'a',
#               'by',
#               'distinct',
#               'beautiful',
#               'a',
#               'their',
#               'smeared',
#               'to',
#               'wasted',
#               'the',
#               'trying',
#               'one',
#               'definitely',
#               'a',
#               'never',
#               'forced',
#               'one',
#               'ok',
#               'supposed',
#               'apparently',
#               'hideous',
#               'swept',
#               'highly',
#               'still',
#               'quite',
#               'a',
#               'only',
#               'an',
#               'great',
#               'the',
#               'to',
#               'not',
#               'the',
#               'the',
#               'located',
#               'the',
#               'only',
#               'always',
#               'tacitly',
#               'not',
#               'great',
#               'one',
#               'the',
#               'totally',
#               'the',
#               'a',
#               'of',
#               'quite',
#               '.',
#               'actually',
#               'and',
#               'about',
#               'about',
#               'endangered',
#               'a',
#               'laughable',
#               'background',
#               'not',
#               'again',
#               'also',
#               'great',
#               'only',
#               'that',
#               'without',
#               'more',
#               'beyond',
#               'now',
#               'quickly',
#               'new',
#               'he',
#               'soon',
#               'of',
#               'the',
#               'like',
#               'a',
#               'where',
#               'what',
#               'deed',
#               'all',
#               'dylan',
#               'a',
#               'terrible',
#               'far',
#               'nine',
#               'a',
#               'where',
#               'eventually',
#               'that',
#               'either',
#               'simply',
#               'better',
#               'an',
#               'like',
#               'the',
#               'not',
#               'cut',
#               'also',
#               'one',
#               'a',
#               ...],
#              'a': ['cartoon',
#               'student',
#               'classic',
#               'pity',
#               'man',
#               'pig',
#               'opening',
#               'terrific',
#               'formal',
#               'third',
#               'technical',
#               'plan',
#               'lost',
#               'bet',
#               'month',
#               'home',
#               'bathroom',
#               'computer',
#               'rich',
#               'bet',
#               'sissy',
#               'future',
#               'bracelet',
#               'vagrant',
#               'woman',
#               'comedy',
#               'tender',
#               'stupid',
#               'brand',
#               'bunch',
#               'museum',
#               'disused',
#               'nice',
#               'stark',
#               'decent',
#               'great',
#               'real',
#               'missed',
#               'few',
#               'couple',
#               'new',
#               'near',
#               'little',
#               'little',
#               'shame',
#               'pretty',
#               'mistake',
#               'bit',
#               'film',
#               'sunken',
#               'classic',
#               'turncoat',
#               'lawyer',
#               'favorite',
#               'mad',
#               'demolition',
#               'realistic',
#               'realistic',
#               'realistic',
#               'way',
#               'story',
#               'director',
#               'lead',
#               'sound',
#               'hard',
#               'ripoff',
#               'plot',
#               'fantastic',
#               'bit',
#               'good',
#               'pretentious',
#               'dark',
#               'family',
#               'more',
#               'perpetual',
#               'backdrop',
#               'fart',
#               'psychological',
#               'little',
#               'hybrid',
#               'thriller',
#               'mystery',
#               'sick',
#               'news',
#               'guy',
#               'third',
#               'watch',
#               '.',
#               'woody',
#               'strange',
#               'slow',
#               'thrilling',
#               'new',
#               'swedish',
#               'heart',
#               'polite',
#               'poem',
#               'lot',
#               'pencil',
#               'funnier',
#               'celebrated',
#               'young',
#               'widening',
#               'deadly',
#               'revelation',
#               're',
#               'director',
#               'couple',
#               'scene',
#               'gay',
#               'slighter',
#               'sandwich',
#               'vending',
#               'movie',
#               'veil',
#               'year',
#               'five',
#               'waste',
#               'stand',
#               'talk',
#               'young',
#               'manuscript',
#               'nurse',
#               'tempest',
#               'teacup',
#               'true',
#               'fan',
#               'stand',
#               'bit',
#               'finely',
#               'bag',
#               'failed',
#               'cult',
#               'quick',
#               'very',
#               'serial',
#               'child',
#               'result',
#               'far',
#               'good',
#               'good',
#               'strange',
#               'walker',
#               'movie',
#               'great',
#               'walker',
#               'true',
#               'book',
#               'young',
#               'life',
#               'serious',
#               'chance',
#               'homosexual',
#               'magazine',
#               'popsicle',
#               'mid',
#               'good',
#               'really',
#               'semi',
#               'very',
#               'plot',
#               'couple',
#               'nap',
#               'popular',
#               'mysterious',
#               'year',
#               'medical',
#               'wonderful',
#               'short',
#               'half',
#               'story',
#               'refreshing',
#               'story',
#               'hitchcockian',
#               'good',
#               'little',
#               'minor',
#               'male',
#               'murder',
#               'boring',
#               'strong',
#               'very',
#               'somewhat',
#               'intriguing',
#               'movie',
#               'great',
#               'predictable',
#               'movie',
#               'hard',
#               'damn',
#               'boring',
#               'horrible',
#               'movie',
#               'great',
#               'waste',
#               'canadian',
#               'little',
#               'false',
#               'director',
#               'worn',
#               'man',
#               'woman',
#               'murder',
#               'more',
#               'regrettably',
#               'good',
#               'new',
#               'year',
#               'meeting',
#               'permanent',
#               'way',
#               'memorable',
#               'somber',
#               'drive',
#               'second',
#               'fourteen',
#               'book',
#               'survivor',
#               'woman',
#               'lot',
#               'few',
#               'movie',
#               'little',
#               'great',
#               'terrific',
#               'compelling',
#               'typical',
#               'horror',
#               'group',
#               'mystery',
#               'preview',
#               'much',
#               'twist',
#               'character',
#               'quentin',
#               'bird',
#               'spotless',
#               'kid',
#               'traffic',
#               'young',
#               'car',
#               'few',
#               'little',
#               'climactic',
#               'pre',
#               'genre',
#               'friend',
#               'friend',
#               'conventionally',
#               'shot',
#               'waste',
#               'review',
#               'quick',
#               'shred',
#               'thriller',
#               'horror',
#               'decade',
#               'radio',
#               'case',
#               'lick',
#               'story',
#               'bikini',
#               'bikini',
#               'bikini',
#               'sort',
#               'very',
#               'few',
#               'few',
#               'cheer',
#               'comic',
#               'while',
#               'collective',
#               'buzz',
#               'high',
#               'headache',
#               'full',
#               'book',
#               'hapless',
#               'picky',
#               'bad',
#               'deep',
#               'genre',
#               'little',
#               'lot',
#               'film',
#               'lot',
#               'fairly',
#               'typically',
#               'will',
#               'gross',
#               'miniature',
#               'certain',
#               'real',
#               'over',
#               'one',
#               'year',
#               'good',
#               'veteran',
#               'role',
#               'boring',
#               'demented',
#               'number',
#               'must',
#               'darkened',
#               'series',
#               'lot',
#               'bikini',
#               'rating',
#               'mission',
#               'documentary',
#               'serious',
#               'horrifying',
#               'man',
#               'monster',
#               'full',
#               'tad',
#               'little',
#               'moment',
#               'thai',
#               'bid',
#               'dhoom',
#               'call',
#               'platform',
#               'road',
#               'backstory',
#               'lot',
#               'non',
#               'tune',
#               'mountain',
#               'little',
#               'little',
#               'blockbuster',
#               'pretty',
#               'rhythm',
#               'pubescent',
#               'blood',
#               'beautiful',
#               'wonderful',
#               'movie',
#               'documental',
#               'religious',
#               'deeper',
#               'semi',
#               'sided',
#               'decent',
#               'better',
#               'good',
#               'sufi',
#               'unique',
#               'unique',
#               'horror',
#               'giant',
#               'cool',
#               'great',
#               'product',
#               'very',
#               'few',
#               'flick',
#               'car',
#               'river',
#               'cartoon',
#               'clear',
#               'movie',
#               'better',
#               'foreign',
#               'movie',
#               'sincere',
#               'preview',
#               'bit',
#               'heroic',
#               'disaster',
#               'nice',
#               'nice',
#               'rating',
#               'real',
#               'good',
#               'second',
#               'film',
#               'film',
#               'magnitude',
#               'crummy',
#               'possible',
#               'mere',
#               'shotgun',
#               'zero',
#               'great',
#               'star',
#               'better',
#               'rainy',
#               'lot',
#               'yashraj',
#               'call',
#               'debt',
#               'don',
#               'man',
#               'yashraj',
#               'villain',
#               'trash',
#               'child',
#               'proper',
#               'year',
#               'better',
#               'handgun',
#               'jot',
#               'million',
#               'rubbish',
#               'mitigating',
#               'fright',
#               're',
#               'case',
#               'more',
#               'couple',
#               'high',
#               'mere',
#               'total',
#               'ghost',
#               'break',
#               'reason',
#               'reason',
#               'damn',
#               'movie',
#               'spectacle',
#               'visual',
#               'tearjerker',
#               'regular',
#               'little',
#               'ready',
#               'bit',
#               'single',
#               'single',
#               'score',
#               'fun',
#               'total',
#               'shame',
#               'heavy',
#               'fan',
#               'hit',
#               'new',
#               'great',
#               'good',
#               'female',
#               'guy',
#               '.',
#               'rating',
#               'rating',
#               'sudden',
#               'high',
#               'or',
#               'etc',
#               'fair',
#               'very',
#               'single',
#               'couple',
#               'complete',
#               'lot',
#               'movie',
#               'bad',
#               'yashraj',
#               'swat',
#               'circle',
#               'night',
#               'tragic',
#               'movie',
#               'simple',
#               'romance',
#               'wonderful',
#               'true',
#               'film',
#               'landmark',
#               'writer',
#               'bikini',
#               'good',
#               'lot',
#               'great',
#               'little',
#               'huge',
#               'boring',
#               'bad',
#               'yashraj',
#               'shock',
#               'weird',
#               'whiff',
#               'movie',
#               'love',
#               'sinking',
#               'treasure',
#               'drawing',
#               'woman',
#               'headache',
#               'wrestler',
#               'starved',
#               'movie',
#               'long',
#               'great',
#               'fictional',
#               'good',
#               'small',
#               'little',
#               'little',
#               'great',
#               'tragic',
#               'movie',
#               'trauma',
#               'look',
#               'connection',
#               'good',
#               'nonsense',
#               'good',
#               'history',
#               'minute',
#               'movie',
#               'beautiful',
#               'while',
#               'movie',
#               'bit',
#               'movie',
#               'bad',
#               'movie',
#               'good',
#               'movie',
#               'lot',
#               'love',
#               'few',
#               'car',
#               'hill',
#               'classic',
#               'solid',
#               'day',
#               'month',
#               'hard',
#               'figment',
#               'run',
#               'great',
#               'powerful',
#               'crew',
#               'waste',
#               'great',
#               'toilet',
#               'condom',
#               'whore',
#               'but',
#               '.',
#               'relatively',
#               'couple',
#               'very',
#               'century',
#               'mass',
#               'little',
#               'little',
#               'good',
#               'european',
#               'break',
#               'little',
#               'sequel',
#               'stroke',
#               'really',
#               'master',
#               'brilliant',
#               'story',
#               'strange',
#               'story',
#               'truthful',
#               'lot',
#               'theater',
#               'bad',
#               'masterpiece',
#               'romantic',
#               'journey',
#               'lifetime',
#               'new',
#               'cult',
#               'la',
#               'desi',
#               'deranged',
#               'call',
#               'femme',
#               'bikini',
#               'saree',
#               'levitating',
#               'cop',
#               'hundred',
#               'thousand',
#               'microsecond',
#               'woman',
#               'tale',
#               'boy',
#               'girl',
#               'couple',
#               'good',
#               'great',
#               'good',
#               'necklace',
#               'valuable',
#               'drawing',
#               'young',
#               'drifter',
#               'tentative',
#               'stuffy',
#               'much',
#               'woman',
#               'proper',
#               'beautiful',
#               'lifeboat',
#               'great',
#               'few',
#               'ton',
#               'well',
#               'lot',
#               'special',
#               'great',
#               'two',
#               'bad',
#               'terrible',
#               'plot',
#               'road',
#               'call',
#               'threadbare',
#               'vendetta',
#               'coherent',
#               'traditional',
#               'handful',
#               'rajasthani',
#               'water',
#               'dirty',
#               'dhanno',
#               'seemingly',
#               'sickeningly',
#               'film',
#               'hollow',
#               'little',
#               'decent',
#               'moment',
#               'test',
#               'romantic',
#               'timeless',
#               'free',
#               'zest',
#               'nasty',
#               'carat',
#               'lot',
#               'rich',
#               'sense',
#               'very',
#               'never',
#               'gorgeous',
#               'gigantic',
#               'wide',
#               'moving',
#               'long',
#               'action',
#               'out',
#               'bad',
#               'feeling',
#               'couple',
#               'yash',
#               'mood',
#               'species',
#               'better',
#               'story',
#               'choreographer',
#               'screenplay',
#               'stunt',
#               'story',
#               'director',
#               'better',
#               'statutory',
#               'void',
#               'flirt',
#               'lover',
#               'vagabond',
#               'rubrics',
#               'mere',
#               'fictional',
#               'lower',
#               'poker',
#               'group',
#               'part',
#               'monument',
#               'language',
#               'cigar',
#               'lifeboat',
#               'back',
#               'male',
#               'recognizable',
#               'reflection',
#               'look',
#               'deeper',
#               'disaster',
#               'voyage',
#               'special',
#               'septune',
#               'historical',
#               'work',
#               'true',
#               'big',
#               'comic',
#               'good',
#               'film',
#               'hit',
#               'huge',
#               'film',
#               'break',
#               'good',
#               'film',
#               'movie',
#               'fine',
#               'break',
#               'good',
#               'serious',
#               'victim',
#               'judge',
#               'high',
#               'look',
#               'great',
#               'superb',
#               'perfect',
#               'reasonable',
#               'super',
#               'while',
#               'minor',
#               'horror',
#               'smart',
#               'virus',
#               'short',
#               'man',
#               'while',
#               'thirthysomething',
#               'documentary',
#               'completely',
#               'tizzy',
#               'few',
#               'while',
#               'couple',
#               'long',
#               'movie',
#               'movie',
#               'few',
#               'little',
#               'pretty',
#               'completely',
#               'victim',
#               'key',
#               'titanic',
#               'way',
#               'problem',
#               'divine',
#               'brief',
#               'joke',
#               'ending',
#               'rejected',
#               'bright',
#               'master',
#               'i',
#               'proper',
#               'thriller',
#               'scene',
#               'woman',
#               'broken',
#               'brief',
#               'guy',
#               'cheap',
#               'stand',
#               'show',
#               'so',
#               'parent',
#               'male',
#               'movie',
#               'different',
#               'year',
#               'moving',
#               'constant',
#               'horror',
#               'kernel',
#               'sudden',
#               'rousing',
#               'rewarding',
#               'payoff',
#               'brief',
#               'masked',
#               'deserted',
#               'loan',
#               'fixer',
#               'posh',
#               'memorable',
#               'slightly',
#               'crucial',
#               'strong',
#               'low',
#               'lot',
#               'much',
#               'lot',
#               'little',
#               'number',
#               'metaphor',
#               'catalyst',
#               'romantic',
#               'posh',
#               'striving',
#               'tv',
#               'pretty',
#               'bit',
#               'dvd',
#               'copy',
#               'rental',
#               'courtroom',
#               'pulitzer',
#               '.',
#               'refreshing',
#               'fabulous',
#               'spoiler',
#               'huge',
#               'gratuitously',
#               'completely',
#               'la',
#               'lot',
#               'parent',
#               'cushion',
#               'tear',
#               'young',
#               'parent',
#               'must',
#               'lot',
#               'less',
#               'liberal',
#               'member',
#               'writer',
#               'lake',
#               'movie',
#               'ruthless',
#               'murderess',
#               'lively',
#               'year',
#               'little',
#               'movie',
#               'steamy',
#               'sudden',
#               'lesbian',
#               'lot',
#               'little',
#               'couple',
#               'miserable',
#               'phone',
#               'reporter',
#               'journey',
#               'mess',
#               'film',
#               'wonderful',
#               'beautiful',
#               'film',
#               'romantic',
#               'person',
#               'beautiful',
#               'film',
#               'film',
#               'first',
#               'sense',
#               'serious',
#               'mentor',
#               'number',
#               'trip',
#               'number',
#               'study',
#               'kid',
#               'bang',
#               'rarity',
#               'child',
#               'brand',
#               'lazy',
#               'copy',
#               'fan',
#               'movie',
#               'movie',
#               'too',
#               'favorite',
#               'slouch',
#               'fitting',
#               'kung',
#               'great',
#               'gem',
#               'fan',
#               'director',
#               'winning',
#               'very',
#               'thrill',
#               'very',
#               'movie',
#               'movie',
#               'man',
#               'lot',
#               'movie',
#               'hasty',
#               'ham',
#               'deleted',
#               'nonsensical',
#               'dark',
#               'mess',
#               'bridge',
#               'blind',
#               'separate',
#               'bonus',
#               'play',
#               'movie',
#               'footnote',
#               'young',
#               'boy',
#               'granddaughter',
#               'young',
#               'western',
#               'hint',
#               'celebrated',
#               'level',
#               'modern',
#               'kid',
#               'society',
#               'foreign',
#               'very',
#               'rooftop',
#               'hotel',
#               'movie',
#               'tear',
#               'good',
#               'story',
#               'street',
#               'little',
#               'boy',
#               'grandson',
#               'documentary',
#               'man',
#               'fictionalized',
#               'disgusting',
#               'director',
#               'good',
#               'once',
#               'movie',
#               'good',
#               'bit',
#               'building',
#               'guy',
#               'car',
#               'flame',
#               'movie',
#               'king',
#               'famous',
#               'person',
#               'precious',
#               'significance',
#               'long',
#               'total',
#               'sad',
#               'thriller',
#               'journey',
#               'good',
#               'must',
#               'conniving',
#               'shallow',
#               'bland',
#               'shite',
#               'pudding',
#               'wonderful',
#               'delight',
#               'family',
#               'tool',
#               'movie',
#               'movie',
#               'film',
#               'good',
#               'real',
#               'bad',
#               'seizure',
#               'big',
#               'good',
#               'message',
#               'film',
#               'because',
#               'half',
#               'beautifully',
#               'time',
#               'famous',
#               'son',
#               'fact',
#               'bond',
#               'terrible',
#               'good',
#               'superb',
#               'drab',
#               'group',
#               'theatre',
#               'motor',
#               'china',
#               'scandal',
#               'shockingly',
#               'true',
#               'street',
#               'unique',
#               'longing',
#               'grandson',
#               'family',
#               'male',
#               'little',
#               'woman',
#               ...],
#              'cartoon': ['comedy', 'film', 'movies', 'than'],
#              'comedy': ['.',
#               '.',
#               'it',
#               '.',
#               '.',
#               'horror',
#               'type',
#               'and',
#               'i',
#               'and',
#               'was',
#               'and',
#               'part',
#               'a',
#               '.',
#               'hour',
#               'set',
#               'that',
#               'filled',
#               'pairings',
#               'relief'],
#              '.': ['it',
#               'my',
#               'the',
#               'when',
#               '.',
#               '.',
#               '.',
#               '.',
#               '.',
#               '.',
#               '.',
#               '.',
#               'at',
#               '.',
#               '.',
#               '.',
#               '.',
#               '.',
#               '.',
#               '.',
#               '.',
#               '.',
#               'high',
#               'a',
#               'student',
#               'i',
#               'what',
#               'starts',
#               'a',
# ...
#               'professionals'],
#              'halitosis': ['whatever'],
#              'whatever': ['.',
#               'and',
#               'it',
#               'they',
#               'valuables',
#               'she',
#               '.',
#               'room'],
#              'intentionally': ['has'],
#              'comic': ['relief',
#               'touch',
#               'sidekick',
#               'act',
#               'relief',
#               'manga',
#               'venture'],
#              'relief': ['no', '.', '.', 'provided'],
#              'music': ['and',
#               '.',
#               'and',
#               'to',
#               'score',
#               'vishal',
#               'is',
#               'wise',
#               'album',
#               'album',
#               'and',
#               'has',
#               '.',
#               'and',
#               'from',
#               'intensifies',
#               'which',
#               'for',
#               'acting',
#               '.',
#               'is',
#               'fun',
#               'sucked',
#               'which',
#               'score',
#               'and',
#               'is',
#               'is',
#               'for',
#               '.',
#               'when',
#               'was',
#               '.',
#               'video',
#               'wouldn',
#               'composer',
#               'for',
#               'this'],
#              'drenched': ['in'],
#              'shadowy': ['pathos'],
#              'pathos': ['.', 'like'],
#              'defined': ['as'],
#              'expressionist': ['in'],
#              'nature': ['using',
#               'of',
#               'and',
#               'while',
#               'of',
#               'through',
#               'instead',
#               'of',
#               'to',
#               '.',
#               'particularly'],
#              'improvisational': ['method'],
#              'method': ['of'],
#              'illicit': ['a', 'as'],
#              'pronounced': ['depth'],
#              'depth': ['of', 'should', 'of', 'to'],
#              'meaning': ['and',
#               'like',
#               'and',
#               'dialogues',
#               'of',
#               'does',
#               'of',
#               'about',
#               'behind',
#               'to'],
#              'truth': ['.',
#               '.',
#               'one',
#               'to',
#               'and',
#               'where',
#               'is',
#               'started',
#               'ardh',
#               'about',
#               'br',
#               'as',
#               'it',
#               'even'],
#              'beyond': ['that',
#               'the',
#               'beautiful',
#               'me',
#               'hormones',
#               'his',
#               'brilliant',
#               'brief',
#               'insulting'],
#              'simply': ['had',
#               'establish',
#               'wasted',
#               'didn',
#               'means',
#               'wasn',
#               'the',
#               'for',
#               'because',
#               'for',
#               'enjoy',
#               'perfect',
#               'seemed',
#               'doesn',
#               'isn',
#               'absurd',
#               'can',
#               'a',
#               'heaping',
#               'awful'],
#              'sympathy': ['for'],
#              'felt': ['only',
#               'more',
#               'real',
#               'as',
#               'rushed',
#               'when',
#               'forced',
#               'ashamed',
#               'nice',
#               'so',
#               'that',
#               'like',
#               'every',
#               'itself',
#               'so',
#               'so',
#               'i',
#               'like'],
#              'contempt': ['for', 'for'],
#              'parade': ['of', 'sequence'],
#              'shuffling': ['whining'],
#              'whining': ['nicotine', 'accusations', 'about'],
#              'nicotine': ['stained'],
#              'stained': ['martyrs', 'screens'],
#              'martyrs': ['in'],
#              'perpetual': ['quest'],
#              'quest': ['for', 'to'],
#              'identity': ['.', 'crisis', 'impersonation'],
#              'amid': ['a'],
#              'backdrop': ['of'],
#              'cosmopolitan': ['affluence'],
#              'affluence': ['and'],
#              'baked': ['brie'],
#              'brie': ['intelligentsia'],
#              'intelligentsia': ['the'],
#              'looms': ['like'],
#              'fart': ['in'],
#              'speaks': ['in', 'several', 'broken', 'in'],
#              'affected': ['platitudes', 'me'],
#              'platitudes': ['and'],
#              'elevated': ['language'],
#              'language': ['between', 'gaps', '.', 'problem', '.', 'films'],
#              'cigarettes': ['.', 'which', '.'],
#              'struggling': ['desperate', 'to', 'with'],
#              'desperate': ['to',
#               'effort',
#               'voice',
#               'to',
#               'mother',
#               'for',
#               'middle',
#               'middle'],
#              'find': ['direction',
#               'the',
#               'that',
#               'the',
#               'and',
#               'this',
#               '.',
#               'it',
#               'a',
#               'out',
#               'to',
#               'is',
#               'a',
#               'his',
#               'out',
#               'it',
#               'that',
#               'plenty',
#               'sad',
#               'a',
#               'every',
#               'an',
#               'it',
#               'this',
#               'him',
#               'if',
#               'a',
#               'out',
#               'out',
#               'that',
#               'it',
#               'the',
#               'a',
#               'an',
#               'so',
#               'a',
#               'her',
#               '.',
#               'a',
#               'so',
#               'it',
#               'that',
#               'gems'],
#              'understanding': ['or', 'of', 'his'],
#              'goes': ['on',
#               'over',
#               'to',
#               'from',
#               'by',
#               'something',
#               'down',
#               '.',
#               'down',
#               'and',
#               'well',
#               'on',
#               'through',
#               'slowly',
#               'on',
#               'they',
#               'so',
#               'for',
#               'into',
#               'to',
#               'ek'],
#              'point': ['where',
#               'of',
#               'of',
#               'of',
#               'has',
#               '.',
#               'of',
#               'of',
#               'i',
#               'by',
#               '.',
#               'set',
#               'of',
#               'completely',
#               'that',
#               'of',
#               '.',
#               'is',
#               'of',
#               'out',
#               'on',
#               'i',
#               'in',
#               'for',
#               'of',
#               'when',
#               'in',
#               'is',
#               'of',
#               'of',
#               'on',
#               'of',
#               'that',
#               'where',
#               'in',
#               'where'],
#              'want': ['to',
#               'to',
#               'to',
#               'to',
#               'to',
#               'to',
#               'to',
#               'to',
#               'to',
#               'to',
#               'most',
#               'its',
#               'to',
#               'to',
#               'rose',
#               'to',
#               'to',
#               'to',
#               'to',
#               'to',
#               'to',
#               'to',
#               'to',
#               'to',
#               'to',
#               'to',
#               'a',
#               'to',
#               'anyone',
#               'their',
#               'to',
#               'to',
#               'to',
#               'my',
#               'the'],
#              'slap': ['all', 'stick'],
#              'resolution': ['it', 'all', '.'],
#              'interminable': ['introspective'],
#              'introspective': ['babble'],
#              'babble': ['.'],
#              'drama': ['taken',
#               'without',
#               'plays',
#               'unpalatable',
#               'displayed',
#               'we',
#               'as',
#               '.',
#               '.',
#               'was',
#               'that',
#               'and',
#               '.',
#               '.',
#               'about',
#               'suspense',
#               'a',
#               'which'],
#              'taken': ['to',
#               'in',
#               'away',
#               'in',
#               '.',
#               'with',
#               'from',
#               'on',
#               'on',
#               'place',
#               'aback'],
#              'extreme': ['beyond',
#               'but',
#               'settings',
#               'poverty',
#               'sarcasm',
#               'violence',
#               'bored'],
#              'ability': ['to', 'to', 'to', 'to', 'to'],
#              'connect': ['.', '.'],
#              'chose': ['to', 'the'],
#              'immersed': ['in'],
#              'themselves': ['we', 'a'],
#              'feel': ['left',
#               'useful',
#               'that',
#               'a',
#               'as',
#               'a',
#               'could',
#               'bad',
#               'about',
#               'sorry',
#               'so',
#               'it',
#               'the',
#               'and',
#               'of',
#               'every',
#               'for',
#               'that',
#               'like',
#               'ripped',
#               'angry',
#               'ripped',
#               'like'],
#              'left': ['out',
#               'to',
#               'a',
#               'two',
#               'you',
#               'the',
#               'to',
#               'such',
#               'and',
#               'aside',
#               'the',
#               'locked',
#               'me',
#               'hacks',
#               'not',
#               'feeling',
#               'unturned',
#               'half',
#               'with'],
#              'reason': ['i',
#               'they',
#               'to',
#               'for',
#               'not',
#               'other',
#               'why',
#               'it',
#               '.',
#               'titanic',
#               'why',
#               '.',
#               'just',
#               'any',
#               'i',
#               'for',
#               'that',
#               'for',
#               'i',
#               'half',
#               'taylor',
#               'all',
#               'in'],
#              'self': ['indulgent',
#               'involved',
#               '.',
#               'hatred',
#               'indulgent',
#               'explanatory',
#               'made',
#               'proclaimed',
#               'respect',
#               'explanation'],
#              'indulgent': ['and', 'that', 'glorified'],
#              'spiritually': ['draining'],
#              'draining': ['.', 'him'],
#              'insistence': ['on'],
#              'promoting': ['his', 'the'],
#              'message': ['through', 'can', 'it', 'you', 'gently', 'of'],
#              'prozac': ['prose'],
#              'prose': ['and'],
#              'distorted': ['film'],
#              'techniques': ['jettisons', '.', 'of'],
#              'jettisons': ['it'],
#              'past': ['the',
#               'the',
#               'has',
#               'and',
#               'fifteen',
#               'scene',
#               'years',
#               '.',
#               'that'],
#              'relevance': ['.'],
#              'highly': ['recommend',
#               'entertained',
#               'recommend',
#               'compelling',
#               'anticipated',
#               'anticipated',
#               'recommended',
#               'recommended',
#               'recommended',
#               'recommended',
#               'recommended',
#               'recommended',
#               'enough',
#               'reminiscent',
#               'dangerous',
#               'recommended',
#               'inappropriate',
#               'industrial'],
#              'recommend': ['this',
#               '.',
#               'about',
#               'it',
#               'it',
#               'seeing',
#               'not',
#               'this',
#               'it',
#               'it',
#               'it',
#               'this',
#               'this',
#               'this',
#               'it',
#               'this',
#               'that',
#               'zombie',
#               'it'],
#              'feeling': ['a',
#               'at',
#               'abandoned',
#               '.',
#               '.',
#               'horrified',
#               'which',
#               'they',
#               'i',
#               'dirty',
#               'like',
#               'hampers'],
#              'happy': ['and', 'with', 'movie', 'to', 'and', 'medium'],
#              'need': ['something',
#               'a',
#               'many',
#               'to',
#               'to',
#               'to',
#               'to',
#               'not',
#               'immediate',
#               'a'],
#              'death': ['.',
#               'of',
#               'to',
#               'poem',
#               'penalty',
#               '.',
#               'situation',
#               'of',
#               'and',
#               'toll',
#               '.',
#               'maybe',
#               'maybe',
#               'for'],
#              'let': ['s',
#               's',
#               'me',
#               's',
#               'you',
#               's',
#               'that',
#               'me',
#               'me',
#               's',
#               'go',
#               'down',
#               'us',
#               's',
#               's',
#               's',
#               's',
#               's',
#               'this',
#               'togepi',
#               's',
#               'alone',
#               'him',
#               'that'],
#              'pretend': ['this', 'we'],
#              'happened': ['.',
#               'in',
#               'on',
#               'to',
#               'to',
#               'making',
#               'definitely',
#               'and',
#               'that',
#               'it',
#               '.',
#               'to',
#               '.'],
#              'comedic': ['robin', 'characters', 'atmosphere'],
#              'robin': ['williams',
#               'williams',
#               's',
#               'wood',
#               'williams',
#               'williams',
#               'williams',
#               'williams',
#               'williams',
#               'williams',
#               'williams',
#               'williams',
#               'williams',
#               'williams',
#               'williams',
#               'williams',
#               'williams',
#               'williams',
#               'williams'],
#              'williams': ['nor',
#               'of',
#               'attempts',
#               'as',
#               '.',
#               'a',
#               'returns',
#               'and',
#               'offers',
#               'toni',
#               'toni',
#               'a',
#               'stars',
#               'gives',
#               'god',
#               'so',
#               'captures',
#               'in',
#               'touches',
#               'who',
#               'and',
#               'gives',
#               'was',
#               'shining',
#               'has',
#               'ex',
#               'to',
#               'in',
#               'friend',
#               'in',
#               'scraggy',
#               'i',
#               'mild',
#               'isn',
#               'long'],
#              'nor': ['is', 'akshay', 'his', 'is', 'sex', 'even', 'is', 'a'],
#              'quirky': ['insane'],
#              'recent': ['thriller',
#               'movies',
#               'years',
#               'r',
#               'years',
#               'foray',
#               'chinese'],
#              'fame': ['.', '.'],
#              'hybrid': ['of'],
#              'dramatization': ['mixed'],
#              'mixed': ['with', 'with', 'with'],
#              'per': ['se', 'se'],
#              'se': ['.', '.', 'en'],
#              ...})

# %%
#define a function for building conditional probabilities

def compute_conditional_probabilities(corpus):
  for key in dictionary.keys():
    
    #getting next word from dictionary
    next_word = dictionary[key]
    
    #remove the duplicate words and save it
    
    unique_words = set(next_word)
    
    num_words = len(next_word)
    
    #placeholder dictionary for the loop
    probabilities_given_key={}
    
    #loop for saving the value of current key
    for unique_word in unique_words:
      
      #save the value of the current words
      probabilities_given_key[unique_word] = float(next_word.count(unique_word))/num_words
  return probabilities_given_key

# %%
#define a function for predicting the probability of the next word
def next_word_predictor(conditional_probabilities,current_word, next_word):
  
  #if current wird is existing, check te probability for the next word
  if current_word in conditional_probabilities:
    
    #if conditional probability of both words exists, return v
    if next_word in conditional_probabilities[current_word]:
      return conditional_probabilities[current_word][next_word]
  
  return 0.0

# %%
conditional_probabilities = compute_conditional_probabilities(corpus)
